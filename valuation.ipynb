# %%
# standard imports

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns
sns.set_palette(sns.color_palette("Spectral"))
sns.set_style("darkgrid")

import datetime

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 1000
mpl.rcParams["axes.labelsize"] = 15
pd.set_option('display.max_columns', 999)

import xlrd

# %%
# Read in Fort Worth and Houston

df_fw = pd.read_excel('Fort Worth NRP LIHTC (2018-2022).xlsx')
df_hou = pd.read_excel('Houston NRP LIHTC (2012-2022).xlsx')

# %%
df_combined = pd.concat([df_fw, df_hou])
df_combined.reset_index(inplace = True)
df_combined.drop(['index', 'Unnamed: 0'], axis = 1, inplace = True)

# %%
df_combined
# Out:
#     Lifecycle                                Portal Name  \
# 0  Stabilized      Broadmoor Apartments (2900 Broadmoor)
# 1  Stabilized  Mercantile Apartments (Mercantile Square)
# 2  Stabilized                          Golden Bamboo III
#
#                             Legal Name     Marketing Name  Units  \
# 0  The Broadmoor at Western Hills Ltd.     2900 Broadmoor    324
# 1          Mercantile Apartments Ltd.   Mercantile Square    324
# 2              Golden Bamboo III, Ltd.                NaN    130
#
#                  Address        City State    Zip           Phone  MSA  \
# 0   2900 Broadmoor Drive  Fort Worth    TX  76116  (817) 769-4677  NaN
# 1  3600 Tanacross Drive   Fort Worth    TX  76137  (682) 224-8777  NaN
# 2        6628 Synott Rd.     Houston    TX  77083    832-328-1986  NaN
#
#                            Email Product Type Rural / Urban HUD  \
# 0     2900Broadmoor@nrpgroup.com           4%         Urban  No
# ...
